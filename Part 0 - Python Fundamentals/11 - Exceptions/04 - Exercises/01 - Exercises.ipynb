# %% [markdown]
# ### Solutions

# %% [markdown]
# #### Question 1

# %% [markdown]
# The following code is meant to calculate the smallest absolute value of a given sequence of numbers.

# %%
values = [1, 2, 3, 4]

minimum = abs(values[0])
for value in values[1:]:
    if abs(value) < minimum:
        minimum = abs(value)
print(f'Minimum is: {minimum}')
# Out:
# Minimum is: 1

# %%
values = []

minimum = abs(values[0])
for value in values[1:]:
    if abs(value) < minimum:
        minimum = abs(value)
print(f'Minimum is: {minimum}')
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[2], line 3
#       1 values = []
# ----> 3 minimum = abs(values[0])
#       4 for value in values[1:]:
#       5     if abs(value) < minimum:
#
# IndexError: list index out of range

# %% [markdown]
# The problem is that if the sequence is empty, it will raise an exception.
#
# Write code such that if the `values` sequence is empty, the calculated minimum is printed as `0`.

# %%
values = []

if len(values) == 0:
    print("The list is empty. Cannot determine the minimum value.")
else:
    minimum = abs(values[0])
    for value in values[1:]:
        if abs(value) < minimum:
            minimum = abs(value)
    print(f'Minimum is: {minimum}')
# Out:
# The list is empty. Cannot determine the minimum value.

# %%
values = [3, -2, 5]

if len(values) == 0:
    print(f'Minimum is: 0')
else:
    minimum = abs(values[0])
    for value in values[1:]:
        if abs(value) < minimum:
            minimum = abs(value)
    print(f'Minimum is: {minimum}')
# Out:
# Minimum is: 2

# %%
values = []

try:
    minimum = abs(values[0])
    for value in values[1:]:
        if abs(value) < minimum:
            minimum = abs(value)
    print(f'Minimum is: {minimum}')
except IndexError:
    print(f'Minimum is : 0')
# Out:
# Minimum is : 0

# %%
values = []

try:
    minimum = abs(values[0])
    for value in values[1:]:
        if abs(value) < minimum:
            minimum = abs(value)
except IndexError:
    minimum = 0 

print(f'Minimum is: {minimum}')
# Out:
# Minimum is: 0

# %%
values = [2, -3 ,4, -1]

try:
    minimum = abs(values[0])
    for value in values[1:]:
        if abs(value) < minimum:
            minimum = abs(value)
except IndexError:
    minimum = 0 

print(f'Minimum is: {minimum}')
# Out:
# Minimum is: 1

# %% [markdown]
# #### Question 2

# %% [markdown]
# Write code that raises the built-in Python exception `ValueError` with a custom message, and catches the exception and prints the custom message.

# %%
raise ValueError('Some custom message')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 raise ValueError('Some custom message')
#
# ValueError: Some custom message

# %%
try:
    raise ValueError('Some custom message')
except ValueError as ex:
    print(ex)
# Out:
# Some custom message
