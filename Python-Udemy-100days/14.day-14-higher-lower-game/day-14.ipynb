# %%
game_data = [
    {
        "name": "Taylor Swift",
        "profession": "Singer",
        "country": "USA",
        "followers": 280  # million
    },
    {
        "name": "Cristiano Ronaldo",
        "profession": "Footballer",
        "country": "Portugal",
        "followers": 620
    },
    {
        "name": "Lionel Messi",
        "profession": "Footballer",
        "country": "Argentina",
        "followers": 500
    },
    {
        "name": "Selena Gomez",
        "profession": "Singer & Actress",
        "country": "USA",
        "followers": 430
    },
    {
        "name": "Dwayne Johnson",
        "profession": "Actor & Wrestler",
        "country": "USA",
        "followers": 395
    },
    {
        "name": "Ariana Grande",
        "profession": "Singer",
        "country": "USA",
        "followers": 380
    },
    {
        "name": "Virat Kohli",
        "profession": "Cricketer",
        "country": "India",
        "followers": 270
    },
    {
        "name": "Beyoncé",
        "profession": "Singer",
        "country": "USA",
        "followers": 315
    }
]

# %%
import random

current_score = 0

while True:

    pick_1, pick_2 = random.sample(game_data, 2)

    print("Welcome to the higer low game!")
    print(f"Your current score: {current_score}")
    print(f"Compare A: {pick_1['name']}, a {pick_1['profession']}, from {pick_1['country']}")
    print("VS")
    print(f"Compare B: {pick_2['name']}, a {pick_2['profession']}, from {pick_2['country']}")
    answer = input("Who has more followers? Type 'A' or 'B'").upper()

    if answer == "A" and int(pick_1["followers"]) > int(pick_2["followers"]):
        current_score += 1
        print("You are right!")
    elif answer == "B" and int(pick_1["followers"]) < int(pick_2["followers"]):
        current_score += 1
        print("You are right!")
    else:
        print("You are Wrong")
        if current_score > 0:
            current_score -= 1 
        else:
            current_score == 0
    
    continue_game = input("Type 'Y' of if you want to continue, 'N' to stop").upper()
    if continue_game == 'N':
        break
# Out:
# Your current score: 0
# Compare A: Ariana Grande, a Singer, from USA
# VS
# Compare B: Dwayne Johnson, a Actor & Wrestler, from USA
# You are Wrong
# Your current score: 0
# Compare A: Cristiano Ronaldo, a Footballer, from Portugal
# VS
# Compare B: Dwayne Johnson, a Actor & Wrestler, from USA
# You are right!
# Your current score: 1
# Compare A: Beyoncé, a Singer, from USA
# VS
# Compare B: Virat Kohli, a Cricketer, from India
# You are right!
# Your current score: 2
# Compare A: Cristiano Ronaldo, a Footballer, from Portugal
# VS
# Compare B: Dwayne Johnson, a Actor & Wrestler, from USA
# You are Wrong
# Your current score: 1
# Compare A: Beyoncé, a Singer, from USA
# VS
# Compare B: Selena Gomez, a Singer & Actress, from USA
# You are right!
# Your current score: 2
# Compare A: Selena Gomez, a Singer & Actress, from USA
# VS
# Compare B: Taylor Swift, a Singer, from USA
# You are right!
# Your current score: 3
# Compare A: Dwayne Johnson, a Actor & Wrestler, from USA
# VS
# ...

# %%
import random

current_score = 0

while True:

    pick_1 = random.choice(game_data)
    pick_2 = random.choice(game_data)

    if pick_1 == pick_2:
        pick_2 = random.choice(game_data)

    print("Welcome to the higer low game!")
    print(f"Your current score: {current_score}")
    print(f"Compare A: {pick_1['name']}, a {pick_1['profession']}, from {pick_1['country']}")
    print("VS")
    print(f"Compare B: {pick_2['name']}, a {pick_2['profession']}, from {pick_2['country']}")
    answer = input("Who has more followers? Type 'A' or 'B'").upper()

    if answer == "A" and int(pick_1["followers"]) > int(pick_2["followers"]):
        current_score += 1
        print("You are right!")
    elif answer == "B" and int(pick_1["followers"]) < int(pick_2["followers"]):
        current_score += 1
        print("You are right!")
    else:
        print("You are Wrong")
        if current_score > 0:
            current_score -= 1 
        else:
            current_score == 0
    
    continue_game = input("Type 'Y' of if you want to continue, 'N' to stop").upper()
    if continue_game == 'N':
        break
