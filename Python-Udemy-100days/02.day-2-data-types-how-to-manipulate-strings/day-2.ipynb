# %%
print("Hello"[0])
# Out:
# H

# %%
print("Hello"[-1])
# Out:
# o

# %%
print("Hello"[1])
# Out:
# e

# %%
len("12345")
# Out:
# 5

# %%
print(type(123))
print(type(1.23))
print(type("123"))
print(type(True))
# Out:
# <class 'int'>
# <class 'float'>
# <class 'str'>
# <class 'bool'>

# %%
print(int("123") + int("456"))
# Out:
# 579

# %%
print("Number of letters in your name: " + str(len(input("Enter your name here"))))
# Out:
# Number of letters in your name: 4

# %%
print(123 + 456)
print(7 - 3)
print(3 * 2)
print(5 / 2)
print(5 // 2) # it execute 6/2 first and then remove the number before "."
print(2 ** 2)
print(2 ** 3)
# Out:
# 579
# 4
# 6
# 2.5
# 2
# 4
# 8

# %%
print(3 * (3+3) /3)
# Out:
# 6.0

# %%
weight = 84
height = 1.65

bmi = 84 / 1.65**2
print(bmi)
# Out:
# 30.85399449035813

# %%
print(int(bmi))
# Out:
# 30

# %%
print(round(bmi,2))
# Out:
# 30.85

# %%
score = 0

# User scores a point
score += 1
print(score)
# Out:
# 1

# %%
# f-strings
print(f"your score is : {score}")
# Out:
# your score is : 1

# %%
# Project 2
print("Welcome to the tip calculator")
bill = float(input("What was the total bill?"))
tip = int(input("How much tip would you like to give? 10, 12, or 15"))
people = int(input("How many people to split the bill?"))
person = round((bill+bill*(tip/100))/people,2)
print(f"Each person should pay: ${person}")
# Out:
# Welcome to the tip calculator
# Each person should pay: $33.6
