# %%
def my_function():
    for i in range(1,21):
        if i == 20:
            print("you got it")

my_function()
# Out:
# you got it

# %%
from random import randint
dice_image = ['a','b','c','d','e','f']
dice_num = randint(1,5)
print(dice_image[dice_num])
# Out:
# b

# %%
year = int(input("What's your year of birth"))

if year > 1980 and year <= 1994:
    print("You are Millenial.")
elif year > 1994:
    print("You are Gen Z.")
# Out:
# You are Gen Z.

# %%
try:
    age = int(input("How old are you?"))
except ValueError:
    print("You have typed in a an invalid number. Please try again with a numerical response such as 15 ")
    age = int(input("How old are you?"))

if age > 18:
    print(f"You can drive at age {age}")
# Out:
# You have typed in a an invalid number. Please try again with a numerical response such as 15
# You can drive at age 19

# %%
word_per_page = 0
pages = int(input("Number of pages: "))
word_per_page = int(input("Number of words per page: "))
total_words = pages * word_per_page

print(f"pages = {pages}")
print(f"words_per_page = {word_per_page}")
print(total_words)
# Out:
# pages = 20
# words_per_page = 20
# 400

# %%
import random
import maths

def mutate(a_list):
    b_list = []
    new_item = 0
    for item in a_list:
        new_item = item*2
        new_item += random.randint(1,3)
        new_item = maths.add(new_item,item)
    b_list.append(new_item)
    print(b_list)


mutate([1,2,3,5,8,13])
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[2], line 2
#       1 import random
# ----> 2 import maths
#       4 def mutate(a_list):
#       5     b_list = []
#
# ModuleNotFoundError: No module named 'maths'
