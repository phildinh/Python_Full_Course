# %%
def format_name(f_name,l_name):
    f_name.title()
    l_name.title()
    print(f_name)
    print(l_name)

format_name("Phil","Dinh")
# Out:
# Phil
# Dinh

# %%
def format_name(f_name,l_name):
    formatted_f_name = f_name.title()
    formatted_l_name = l_name.title()
    return f"{formatted_f_name}{formatted_l_name}"

print(format_name("phil","dinh"))
# Out:
# PhilDinh

# %%
def function_1(text):
    return text + text

def function_2(text):
    return text.title()

output = function_2(function_1("hello"))
print(output)
# Out:
# Hellohello

# %%
# Project challenge
cal = 0

first_num = float(input("what's the first number? :"))
select_cal = input("+\n-\n*\n/")
second_num = float(input("What's the next number? :"))

def calculation(first_num,select_cal,second_num):
    if select_cal == "+":
        cal = first_num + second_num
        return cal
    elif select_cal == "-":
        cal = first_num - second_num
        return cal
    elif select_cal == "*":
        cal = first_num * second_num
        return cal
    elif select_cal == "/":
        cal = first_num / second_num
        return cal
    
output = calculation(first_num,select_cal,second_num)
print(f"{first_num} {select_cal} {second_num} = {output}")

cal_1 = 0
cal_2 = float(output)
stop = False

while not stop:
    select = input(f"Type 'Y' to continue calculating with {output}, or type 'N' to start a new calculation or 'C' to stop").lower()
    if select == "y":

        second_num = float(input("What's the next number? :"))
        select_cal = input("+\n-\n*\n/")

        def calculation(cal_2,select_cal,second_num):
            if select_cal == "+":
                cal_1 = cal_2 + second_num
                return cal_1
            elif select_cal == "-":
                cal_1 = cal_2 - second_num
                return cal_1
            elif select_cal == "*":
                cal_1 = cal_2 * second_num
                return cal_1
            elif select_cal == "/":
                cal_1 = cal_2 / second_num
                return cal_1
            
        output_2 = calculation(cal_2,select_cal,second_num)
        print(f"{cal_2} {select_cal} {second_num} = {output_2}")

        cal_2 = output_2
        output = output_2

    elif select == "n":

        cal = 0

        first_num = float(input("what's the first number? :"))
        select_cal = input("+\n-\n*\n/")
        second_num = float(input("What's the next number? :"))

        def calculation(first_num,select_cal,second_num):
            if select_cal == "+":
                cal = first_num + second_num
                return cal
            elif select_cal == "-":
                cal = first_num - second_num
                return cal
            elif select_cal == "*":
                cal = first_num * second_num
                return cal
            elif select_cal == "/":
                cal = first_num / second_num
                return cal
            
        output = calculation(first_num,select_cal,second_num)
        print(f"{first_num} {select_cal} {second_num} = {output}")

    else:

        stop = True
        print("Stop our calculation!")
# Out:
# 15.0 + 20.0 = 35.0
# 35.0 + 40.0 = 75.0
# 75.0 - 50.0 = 25.0
# 25.0 + 100.0 = 125.0
# 15.0 * 20.0 = 300.0
# Stop our calculation!

# %%
def calculation(a, op, b):
    if op == "+":
        return a + b
    elif op == "-":
        return a - b
    elif op == "*":
        return a * b
    elif op == "/":
        return a / b
    
first_num = float(input("what's the first number? :"))
select_cal = input("+\n-\n*\n/")
second_num = float(input("What's the next number? :"))

output = calculation(first_num,select_cal,second_num)
print(f"{first_num} {select_cal} {second_num} = {output}")

while True:

    select = input(f"Type 'Y' to continue {output}, 'N' to start new, or 'C' to finish").lower()

    if select == "y":
        second_num = float(input("What's the next number? :"))
        select_cal = input("+\n-\n*\n/")

        output_2 =  calculation(output,select_cal,second_num)
        print(f"{output} {select_cal} {second_num} = {output_2}")

        output = output_2

    elif select == "n":
        first_num = float(input("what's the first number? :"))
        select_cal = input("+\n-\n*\n/")
        second_num = float(input("What's the next number? :"))

        output = calculation(first_num,select_cal,second_num)
        print(f"{first_num} {select_cal} {second_num} = {output}")

    else:
        break
# Out:
# 30.0 + 15.0 = 45.0
# 45.0 + 50.0 = 95.0
# 95.0 + 100.0 = 195.0
