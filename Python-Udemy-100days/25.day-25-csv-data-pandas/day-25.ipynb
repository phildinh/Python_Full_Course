# %%
import pandas as pd

# %%
df = pd.read_csv("weather_data.csv")
df.head()
# Out:
#          day  temp condition
# 0     Monday    12     Sunny
# 1    Tuesday    14      Rain
# 2  Wednesday    15      Rain
# 3   Thursday    14    Cloudy
# 4     Friday    21     Sunny

# %%
df.dtypes
# Out:
# day          object
# temp          int64
# condition    object
# dtype: object

# %%
df_dict = df.to_dict()
df_dict
# Out:
# {'day': {0: 'Monday',
#   1: 'Tuesday',
#   2: 'Wednesday',
#   3: 'Thursday',
#   4: 'Friday',
#   5: 'Saturday',
#   6: 'Sunday'},
#  'temp': {0: 12, 1: 14, 2: 15, 3: 14, 4: 21, 5: 22, 6: 24},
#  'condition': {0: 'Sunny',
#   1: 'Rain',
#   2: 'Rain',
#   3: 'Cloudy',
#   4: 'Sunny',
#   5: 'Sunny',
#   6: 'Sunny'}}

# %%
df_dict = df["temp"].to_list()
df_dict
# Out:
# [12, 14, 15, 14, 21, 22, 24]

# %%
df_temp_avg = df["temp"].mean() 
print(df_temp_avg)
# Out:
# 17.428571428571427

# %%
df_temp_avg = sum(df_dict) / len(df_dict)
df_temp_avg
# Out:
# 17.428571428571427

# %%
print(df["temp"].max())
# Out:
# 24

# %%
print(df["condition"])
# Out:
# 0     Sunny
# 1      Rain
# 2      Rain
# 3    Cloudy
# 4     Sunny
# 5     Sunny
# 6     Sunny
# Name: condition, dtype: object

# %%
df.condition
# Out:
# 0     Sunny
# 1      Rain
# 2      Rain
# 3    Cloudy
# 4     Sunny
# 5     Sunny
# 6     Sunny
# Name: condition, dtype: object

# %%
df[df.day == "Monday"]
# Out:
#       day  temp condition
# 0  Monday    12     Sunny

# %%
df[df.temp == df.temp.max()]
# Out:
#       day  temp condition
# 6  Sunday    24     Sunny

# %%
squir = pd.read_csv("2018_Central_Park_Squirrel_Census_-_Squirrel_Data.csv")
squir.head()
# Out:
#            X          Y Unique Squirrel ID Hectare Shift      Date  \
# 0 -73.956134  40.794082     37F-PM-1014-03     37F    PM  10142018
# 1 -73.957044  40.794851     37E-PM-1006-03     37E    PM  10062018
# 2 -73.976831  40.766718      2E-AM-1010-03     02E    AM  10102018
# 3 -73.975725  40.769703      5D-PM-1018-05     05D    PM  10182018
# 4 -73.959313  40.797533     39B-AM-1018-01     39B    AM  10182018
#
#    Hectare Squirrel Number       Age Primary Fur Color Highlight Fur Color  \
# 0                        3       NaN               NaN                 NaN
# 1                        3     Adult              Gray            Cinnamon
# 2                        3     Adult          Cinnamon                 NaN
# 3                        5  Juvenile              Gray                 NaN
# 4                        1       NaN               NaN                 NaN
#
#    ...   Kuks  Quaas  Moans Tail flags Tail twitches  Approaches  Indifferent  \
# ...

# %%
squir_grey = len(squir[squir["Primary Fur Color"] == "Gray"])
squir_red = len(squir[squir["Primary Fur Color"] == "Cinnamon"])
squir_black = len(squir[squir["Primary Fur Color"] == "Black"])
print(squir_grey)
print(squir_grey)
print(squir_black)
# Out:
# 2473
# 2473
# 103

# %%
data_dict = {
    "Fur Color": ["Gray","Cinnamon", "Black"],
    "Count: ": [squir_grey,squir_red,squir_black]
}

# %%
new_squir = pd.DataFrame(data_dict)
new_squir
df.to_csv("new_squir.csv")
