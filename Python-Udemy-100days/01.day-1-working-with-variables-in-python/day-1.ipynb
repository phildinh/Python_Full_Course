# %%
print("hello")
# Out:
# hello

# %%
print("hello\nhello\nhello")
# Out:
# hello
# hello
# hello

# %%
print("Hello" + " " + "Phil")
# Out:
# Hello Phil

# %%
input("What is your name?")
# Out:
# 'Phil'

# %%
print("Hello" + " " + input("What is your name?"))
# Out:
# Hello Phil

# %%
# Press Ctrl + / to add #
print("Hello" + " " + input("What is your name?"))
# Out:
# Hello Phil

# %%
name = input("What is your name?")
print(name)
# Out:
# Phil

# %%
name
# Out:
# 'Phil'

# %%
print(len(name))
# Out:
# 4

# %%
len(input("What is your name?"))
# Out:
# 4

# %%
name = input("What is your name?")

# %%
length = len(name)
print(length)
# Out:
# 2

# %%
#Project

Run = "Welcome to the Band Name Generator"
print(Run)
city = input("What's the name of the city you grew up in?\n")
print(city)
name = input("what's your pet's name?\n")
print(name)
print("your band name could be" + city + " " + name)
# Out:
# Welcome to the Band Name Generator
# Vietnam
# Phil
# your band name could beVietnam Phil

# %%
Run
# Out:
# 'Welcome to the Band Name Generator /nphil'
