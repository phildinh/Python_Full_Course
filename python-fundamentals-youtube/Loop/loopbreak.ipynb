# %%
names = ['john','maria','','phil']
for name in names:
    if name == '':
        print('empty value detected!')
        break
    print(f"name: = {name}")
# Out:
# name: = john
# name: = maria
# empty value detected!

# %%
names = ['john','maria','','phil']
for name in names:
    if name == '':
        print('empty value detected!')
        continue
    print(f"name: = {name}")
# Out:
# name: = john
# name: = maria
# empty value detected!
# name: = phil

# %%
names = ['john','maria','','phil']
for name in names:
    if name == '':
        print('empty value detected!')
        pass #todo: Handle Empty Value
        # name = name.replace("insert")
    print(f"name: = {name}")
# Out:
# name: = john
# name: = maria
# empty value detected!
# name: =
# name: = phil

# %%
days = ['Mon','Sun','Wed','Tue']
weekend = ['Sun','Sat']


for day in days:
    if day in weekend:
        continue
    print(f"workday: {day}")
# Out:
# workday: Mon
# workday: Wed
# workday: Tue

# %%
emails = [
    'data@gmail.com',
    'dasdasda@outlook.de',
    'DROP TABLE USERS;',
    'maria@gmail.com'
]

for email in emails:
    if ';' in email:
        print('SQL injection: Hacker Attack')
        break
    print(f"processing email: {email}")
# Out:
# processing email: data@gmail.com
# processing email: dasdasda@outlook.de
# SQL injection: Hacker Attack
