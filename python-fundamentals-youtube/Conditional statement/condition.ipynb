# %%
# condition example
score = 50
if score >= 90:
    print("A")
else:
    print("F")
# Out:
# F

# %%
# elif statement:
score = 82

if score >= 90:
    print("A")
elif score >= 80:
    print("B")
elif score >= 70:
    print("C")
elif score >= 60:
    print("D")
else:
    print("F")
# Out:
# B

# %%
# nested if statement:
score = 82
submitted_project = True

if submitted_project == True:   
    if score >= 90:
        print("A")
    elif score >= 80:
        print("B")
    elif score >= 70:
        print("C")
    elif score >= 60:
        print("D")
    else:
        print("F")
else:
    print("Need to submit project")
# Out:
# B

# %%
# Challenge
# Email must contain a "." and "@"
# Email must contain exactly one '@' symbol
# Email must end with '.com', '.org' or '.net'
# Email must not be longer than 254 characters
# Email must start and end with a letter or digit

email = "phildinh@data."

if email == "":
    print("Email cannot be empty")
else:
    if "." in email and "@" in email:
        if email.count("@") == 1:
            if email.endswith(".com") or email.endswith(".org") or email.endswith(".net"):
                if len(email) < 254:
                    if email[0].isalnum() and email[-1].isalnum():
                        print("Email is valid")
                    else:
                        print("Email must start and end with a letter or digit")
                else:
                    print("Email must not be longer than 254 characters")
            else:
                print("Email must end with '.com', '.org' or '.net'")
        else:
            print("Email must contain exactly one '@' symbol")
    else:
        print("Email must contain a '.' and '@'")
# Out:
# Email must end with '.com', '.org' or '.net'

# %%
# Challenge
# Email must contain a "." and "@"
# Email must contain exactly one '@' symbol
# Email must end with '.com', '.org' or '.net'
# Email must not be longer than 254 characters
# Email must start and end with a letter or digit

email = "phildinh@data."

if email == "":
    print("Email cannot be empty")
elif not("." in email and "@" in email):
    print("Email must contain a '.' and '@'")
elif email.count("@") != 1:
    print("Email must contain exactly one '@' symbol")
elif not email.endswith((".com",".org",".net")):
    print("Email must end with '.com', '.org' or '.net'")
elif len(email) < 254:
    print("Email must not be longer than 254 characters")
elif email[0].isalnum() and email[-1].isalnum():
    print("Email is valid")
# Out:
# Email must end with '.com', '.org' or '.net'

# %%
email = "phildinh@data.com"
# clean the mail
email = email.strip()
# Email must not be empty
if email == "":
    print("Email cannot be empty")
# Email must contain a "." and "@"
elif not ("." in email and "@" in email):
    print("Email must contain a '.' and '@'")
# Email must contain exactly one '@' symbol
elif email.count("@") != 1:
    print("Email must contain exactly one '@' symbol")
# Email must end with '.com', '.org' or '.net'
elif not email.endswith((".com", ".org", ".net")):
    print("Email must end with '.com', '.org' or '.net'")
# Email must not be longer than 254 characters
elif len(email) >= 254:
    print("Email must not be longer than 254 characters")
# Email must start and end with a letter or digit
elif not (email[0].isalnum() and email[-1].isalnum()):
    print("Email must start and end with a letter or digit")

else:
    print("Email is valid")
# Out:
# Email is valid

# %%
# Python challenge 2 for passwords
# Must not be empty
# must be at least 8 characters
# must include at least 1 uppercase
# must include at least 1 lowercase
# must not be same as the email
# must not contain any spaces
# must tart and end with a letter or digit

passwords = "Phildinh@data.com"

# Must not be empty
if passwords == "":
    print("password can not be empty")
# must be at least 8 characters
elif not len(passwords) > 8:
    print("must be at least 8 characters")
# must include at least 1 uppercase
elif not any(ch.isupper() for ch in passwords):
    print("must include at least 1 uppercase")
# must include at least 1 lowercase
elif not any(ch.islower() for ch in passwords):
    print("must include at least 1 uppercase")
# must not be same as the email
elif passwords == email:
    print("# must not be same as the email")
# must not contain any spaces
elif not passwords == passwords.strip():
    print("must not contain any spaces")
# must tart and end with a letter or digit
elif not (passwords[0].isalnum() and passwords[-1].isalnum()):
    print("Email must start and end with a letter or digit")
else:
    print("passwords is valid")
# Out:
# passwords is valid
