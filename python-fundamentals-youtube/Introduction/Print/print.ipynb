# %%
# Double Quote Example
print("Hello \"")
# Out:
# Hello "

# %%
print("Hello \"Python\"")
# Out:
# Hello "Python"

# %%
# single quote example
print('Hello \'')
# Out:
# Hello '

# %%
# Baclslash Example
print("This is a backslash: \\")
# Out:
# This is a backslash: \

# %%
# New Line Example
print("Hello\nWorld")
# Out:
# Hello
# World

# %%
# tab Example
print("Hello\tWorld")
# Out:
# Hello	World

# %%
# backspace Example
print("Hello\bWorld")
# Out:
# HellWorld

# %%
print("Your Learning Path:\n - Python Basics\n - Data Engineering\n - AI")
# Out:
# Your Learning Path:
#  - Python Basics
#  - Data Engineering
#  - AI

# %%
print("""Your Learning Path:
 - Python Basics
 - Data Engineering
 - AI""")
# Out:
# Your Learning Path:
#  - Python Basics
#  - Data Engineering
#  - AI
