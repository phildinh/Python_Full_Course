# %%
x = 1
print(x)
# Out:
# 1

# %%
x = 1
x = 2
print(x)
# Out:
# 2

# %%
print(x + 3)
# Out:
# 5

# %%
y = x + 3
print(y)
# Out:
# 5

# %%
name = "Phil"
print("my name is " + name)
print("my name is {}".format(name))
print(f"my name is {name}")
print(name , "is learning Python")
print("my name is", name)
# Out:
# my name is Phil
# my name is Phil
# my name is Phil
# Phil is learning Python
# my name is Phil

# %%
name = "datawithphil"
print(f"info@{name}.com\nsupport@{name}.com\nwww.{name}.com")
# Out:
# info@datawithphil.com
# support@datawithphil.com
# www.datawithphil.com

# %%
name = "datawithphil"
print("info@{}.com\nsupport@{}.com\nwww.{}.com".format(name, name, name))
# Out:
# info@datawithphil.com
# support@datawithphil.com
# www.datawithphil.com

# %%
name = "datawithphil"
print("info@", name, ".com\nsupport@", name, ".com\nwww.", name, ".com", sep="")
# Out:
# info@datawithphil.com
# support@datawithphil.com
# www.datawithphil.com
