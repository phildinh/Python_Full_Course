# %%
print(True)
print(False)
print(type(True))
print(type(False))
print(bool(123))
print(bool(0))
print(bool("Hello"))
print(bool(""))
print(bool([1, 2, 3]))
# Out:
# True
# False
# <class 'bool'>
# <class 'bool'>
# True
# False
# True
# False
# True

# %%
email = ""
phone = "123-456-7890"
username = "user123"
# Allows registeration
# If any field is filled
print(any([email, phone, username]))

# Allows registeration
# only of all frields is filled
print(all([email, phone, username]))

print(isinstance(True, bool))
print(isinstance(1, bool))
print(isinstance(False, bool))
# Out:
# True
# False
# True
# False
# True
