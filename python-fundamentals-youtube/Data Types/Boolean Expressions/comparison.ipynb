# %%
# comparision operators in python
print(10 == 10)  # True
print(10 != 5)   # True
print(10 > 5)    # True
print(5 < 10)    # True
print(3 >= 3)   # True
# Out:
# True
# True
# True
# True
# True

# %%
print("a" < "b")
print("apple" > "banana")
print("apple" == "apple")
print( 5 < 3 < 10)  # Chained comparison
# Out:
# True
# False
# True
# False
