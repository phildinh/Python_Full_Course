# %%
# data types
a = 10           # integer
b = 3,14        # float
c = "Hello"     # string
d = True        # boolean
e = "1234"   # string representing a number
h = None        # NoneType
i = ""         # empty string
j = " "       # string with whitespace

# %%
# function example
# function_name(value)
print("hello world")
# Out:
# hello world

# %%
# methods example
# value.method_name()
"hello".upper()
# Out:
# 'HELLO'

# %%
text = "hi"
number = 10

print(type(text))
print(type(number))
# Out:
# <class 'str'>
# <class 'int'>

# %%
text = "hi"
number = 10

print(len(text))
print(len(number))
# Out:
# 2
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[9], line 5
#       2 number = 10
#       4 print(len(text))
# ----> 5 print(len(number))
#
# TypeError: object of type 'int' has no len()

# %%
text = "hi"
number = 10

print(text.upper())
print(number.bit_length())
# Out:
# HI
# 4

# %%
# example challenge
my_age = 29
my_height = 175.5
my_name = "Phil"
are_you_student = False
empty_string = ""

print(type(my_age))
print(type(my_height))
print(type(my_name))
print(type(are_you_student))
print(type(empty_string))
# Out:
# <class 'int'>
# <class 'float'>
# <class 'str'>
# <class 'bool'>
# <class 'str'>
